# %%
import pandas as pd
from sklearn.model_selection  import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/damodargupta/Desktop/ML/wine/wine.data')
df
# Out:
#     Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 1     14.23        1.71  2.43               15.6        127           2.80
# 1     13.20        1.78  2.14               11.2        100           2.65
# 1     13.16        2.36  2.67               18.6        101           2.80
# 1     14.37        1.95  2.50               16.8        113           3.85
# 1     13.24        2.59  2.87               21.0        118           2.80
# ..      ...         ...   ...                ...        ...            ...
# 3     13.71        5.65  2.45               20.5         95           1.68
# 3     13.40        3.91  2.48               23.0        102           1.80
# 3     13.27        4.28  2.26               20.0        120           1.59
# 3     13.17        2.59  2.37               20.0        120           1.65
# 3     14.13        4.10  2.74               24.5         96           2.05
#
# ...

# %%
df.isnull().sum()
# Out:
# Alcohol                         0
# Malic acid                      0
# Ash                             0
# Alcalinity of ash               0
# Magnesium                       0
# Total phenols                   0
# Flavanoids                      0
# Nonflavanoid phenols            0
# Proanthocyanins                 0
# Color intensity                 0
# Hue                             0
# OD280/OD315 of diluted wines    0
# Proline                         0
# dtype: int64

# %%
# independent and dependent variables

X = df.iloc[: , :-1]
y = df.iloc[: , -1] # taking proline as our target variable

# %%
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size=0.33 , random_state=42)

# %%
X_train
# Out:
#     Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 1     13.71        1.86  2.36               16.6        101           2.61
# 3     13.88        5.04  2.23               20.0         80           0.98
# 2     12.29        1.41  1.98               16.0         85           2.55
# 2     12.21        1.19  1.75               16.8        151           1.85
# 3     12.82        3.37  2.30               19.5         88           1.48
# ..      ...         ...   ...                ...        ...            ...
# 2     13.86        1.51  2.67               25.0         86           2.95
# 2     12.25        1.73  2.12               19.0         80           1.65
# 1     14.38        1.87  2.38               12.0        102           3.30
# 2     12.69        1.53  2.26               20.7         80           1.38
# 2     12.34        2.45  2.46               21.0         98           2.56
#
# ...

# %%
scalar = StandardScaler()
X_train_scaled = scalar.fit_transform(X_train)
X_test_scaled = scalar.transform(X_test)

# %%
## PCA- Transformation
pca=PCA(n_components=12)
pca
# Out:
# PCA(n_components=12)

# %%
X_train_pca = pca.fit_transform(X_train_scaled)
X_train_pca
# Out:
# array([[-2.34476307, -0.00620826, -0.28812658, ...,  0.19814033,
#          0.56721448, -0.10189112],
#        [ 4.08078014, -0.30645406, -1.45385654, ...,  0.19184486,
#         -0.48636517,  0.34683078],
#        [-1.56832848,  2.04427647, -1.29502611, ..., -0.04287029,
#         -0.10866686,  0.06998745],
#        ...,
#        [-3.46574459, -2.03870522, -1.18552799, ...,  0.72695279,
#         -0.11082666, -0.15441411],
#        [ 1.45584805,  1.80100465,  0.05962997, ...,  0.63366214,
#         -0.40096439,  0.31252544],
#        [-0.28158081,  0.81811096,  0.77854144, ..., -0.0562545 ,
#         -0.03563793, -0.24234807]])

# %%
explained_variance = pca.explained_variance_ratio_
explained_variance
# Out:
# array([0.36859111, 0.17384554, 0.12833567, 0.0802317 , 0.07111708,
#        0.04647313, 0.03910197, 0.02870933, 0.02066474, 0.02006096,
#        0.01435447, 0.00851428])

# %%
# Plot the explained variance ratio
explained_variance = pca.explained_variance_ratio_
plt.bar(range(1, len(explained_variance) + 1), explained_variance)
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.title('Explained Variance Ratio for Each Principal Component')
plt.show()

# %% [markdown]
# ### we get to know that the first three principal components capture almost 65 % of the variance of the whole dataset. so we select these 3 principal components.

# %%
# Scatter plot of the first three principal components
from mpl_toolkits.mplot3d import Axes3D

# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_train_pca[:, 0], X_train_pca[:, 1], X_train_pca[:, 2], c='red', cmap='viridis')
ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')
ax.set_title('PCA Results (First Three Components)')
plt.show()
# Out:
# /var/folders/pb/3pqt97t1701c0435w57nfgrh0000gn/T/ipykernel_22775/3637412540.py:7: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(X_train_pca[:, 0], X_train_pca[:, 1], X_train_pca[:, 2], c='red', cmap='viridis')

# %%
from sklearn.cluster import KMeans

# Specify the number of clusters
n_clusters = 3  # You can choose a different number

# Create a K-Means clustering object
kmeans = KMeans(n_clusters=n_clusters)

# Fit the K-Means model to the PCA-transformed data
kmeans.fit(X_train_pca)

# Get the cluster labels
cluster_labels = kmeans.labels_
# Out:
# /Users/damodargupta/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Assuming X_pca contains the PCA-transformed data with 3 components
# Assuming cluster_labels contains the cluster assignments obtained from K-Means

# Create a 3D scatter plot with different colors for each cluster
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Define colors for each cluster
cluster_colors = ['red', 'green', 'blue']  # You can add more colors for additional clusters

# Scatter plot each data point with a color corresponding to its cluster
for i in range(len(X_train_pca)):
    ax.scatter(X_train_pca[i, 0], X_train_pca[i, 1], X_train_pca[i, 2], c=cluster_colors[cluster_labels[i]], marker='o')

ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')
ax.set_title('K-Means Clustering Results on PCA-transformed Data')
plt.show()

# %%
# table showing performance metrics for clustering algorithm
import pandas as pd
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score

# Assuming you have ground truth labels for comparison (not always available in unsupervised clustering)
# Replace 'true_labels' with the true labels if available
# If you don't have ground truth labels, consider using internal validation metrics

# Calculate clustering performance metrics
silhouette = silhouette_score(X_train_pca, cluster_labels)  # Silhouette Score
calinski_harabasz = calinski_harabasz_score(X_train_pca, cluster_labels)  # Calinski-Harabasz Score
davies_bouldin = davies_bouldin_score(X_train_pca, cluster_labels)  # Davies-Bouldin Index

# Create a dictionary with performance metrics
performance_metrics = {
    'Silhouette Score': [silhouette],
    'Calinski-Harabasz Score': [calinski_harabasz],
    'Davies-Bouldin Index': [davies_bouldin]
}

# Create a DataFrame to display the metrics
metrics_df = pd.DataFrame(performance_metrics)

# Display the table of performance metrics
print(metrics_df)
# Out:
#    Silhouette Score  Calinski-Harabasz Score  Davies-Bouldin Index
# 0          0.258794                43.970703              1.511062

# %% [markdown]
# ## these are the clusters that highlight the data points for principal components that capture the highest variance.
# ## In order, PC1 Captures about 36 percent , then PC2 captures 17 percent and then PC3 captures 12 percent
